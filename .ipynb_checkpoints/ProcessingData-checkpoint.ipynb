# %% [markdown]
# ## Load packages

# %%
import env
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy import displacy
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from operator import itemgetter
import datetime as dt
import matplotlib.dates as mdates
import json

# %% [markdown]
# ## Conncet to database

# %%
conn = sqlite3.connect(env.DB_URL)
cur = conn.cursor()

df = pd.read_sql("SELECT id,Titel,Body,Kategorie,Datum,Quelle FROM Artikel WHERE Quelle ='Reuters'", conn, index_col="id", parse_dates=True)
df.shape
df.head()
# Out:
#                                                 Titel  \
# id
# 1   China smartphone maker Vivo says to suspend al...
# 2   China row threatens to upstage league's return...
# 3   Chinese state media slams basketball's NBA in ...
# 4   NBA fans in China seek refund from Tencent as ...
# 5   Shanghai Sports Federation says NBA fan event ...
#
#                                                  Body        Kategorie  \
# id
# 1   Chinese smartphone maker Vivo said on Tuesday ...  Weltnachrichten
# 2   The NBA returned to Japan for the first time i...  Weltnachrichten
# 3   Chinese state media on Wednesday accused the N...  Top-Nachrichten
# 4   Some Chinese National Basketball Association (...  Top-Nachrichten
# 5   The Shanghai Sports Federation said on Wednesd...  Top-Nachrichten
#
#                   Datum   Quelle
# id
# 1   2019-10-08 00:00:00  Reuters
# 2   2019-10-08 00:00:00  Reuters
# 3   2019-10-09 00:00:00  Reuters
# 4   2019-10-09 00:00:00  Reuters
# 5   2019-10-09 00:00:00  Reuters

# %%
df.shape
# Out:
# (235, 5)

# %% [markdown]
# ## Save as csv

# %%
df.to_csv(path_or_buf="./data/news_en.csv", sep=',',encoding='utf-8')

# %% [markdown]
# ## Count articles per day

# %%
artikelliste={}

for i in range(0, len(df)):
    datum = df.iloc[i]['Datum']
    datum = datum.split(" ")[0]
    
    if datum in artikelliste:
        artikelliste[datum] += 1
    else:
        artikelliste[datum] = 1

# %%
startdatum = "2019-09-22"
enddatum = "2019-10-10"

datelist = pd.date_range(start=startdatum, end=enddatum).tolist()
datelist = pd.to_datetime((datelist))

artikelliste0 =[]
for date in datelist:
    if str(date).split()[0] in artikelliste:
        artikelliste0.append(artikelliste[str(date).split()[0]])
    else:
        artikelliste0.append(0)
        
tickslist = pd.date_range(start=startdatum, end=enddatum, freq='1D').tolist()

plt.plot(datelist, artikelliste0, label="Article count")
plt.axis([startdatum, enddatum, 0, max(artikelliste0)])

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
plt.xlabel('Date')
plt.xticks(tickslist)
plt.ylabel('Count')
plt.suptitle('Articles per day')
plt.gcf().autofmt_xdate()
plt.legend()
plt.savefig('./images/anzahl_en.png', dpi=300)
plt.show()

# %% [markdown]
# ## Mark persons and organizations

# %%
colors = {'ORG': 'red', 'PERSON':'yellow'}
options = {'ents': ['ORG', 'PERSON'], 'colors': colors}
for i in range(0, 10):
    titel = df.iloc[i]['Titel']
    body = df.iloc[i]['Body']
    doc = nlp(titel)
    doc.user_data['title'] = 'Persons in titel ' + str(i)
    displacy.render(doc, style='ent', jupyter=True, options=options )
# Out:
# <h2 style="margin: 0">Persons in titel 0</h2>
#
# <div class="entities" style="line-height: 2.5">Exclusive: With six months to go before Brexit, 630 finance jobs have left -
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  survey</div>
# <h2 style="margin: 0">Persons in titel 1</h2>
#
# <div class="entities" style="line-height: 2.5">Brexit and the City: A barometer for London's financial outlook</div>
# <h2 style="margin: 0">Persons in titel 2</h2>
#
# <div class="entities" style="line-height: 2.5">Brexit at breaking point? Diary dates for Britain's
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     EU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  departure</div>
# <h2 style="margin: 0">Persons in titel 3</h2>
#
# <div class="entities" style="line-height: 2.5">Factbox:
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  surveys UK financial services jobs post-Brexit</div>
# <h2 style="margin: 0">Persons in titel 4</h2>
#
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Bill Cosby
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , in cuffs, imprisoned for up to 10 years for sexual assault</div>
# <h2 style="margin: 0">Persons in titel 5</h2>
#
# <div class="entities" style="line-height: 2.5">Florence-triggered flooding washes into South Carolina</div>
# <h2 style="margin: 0">Persons in titel 6</h2>
#
# <div class="entities" style="line-height: 2.5">Exclusive: Turkey's
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Erdogan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  says court will decide fate of detained U.S. pastor</div>
# <h2 style="margin: 0">Persons in titel 7</h2>
#
# <div class="entities" style="line-height: 2.5">Japan lunar exploration firm to head for moon on SpaceX rockets</div>
# <h2 style="margin: 0">Persons in titel 8</h2>
#
# <div class="entities" style="line-height: 2.5">Brent oil trades near four-year high, but U.S. crude retreats</div>
# <h2 style="margin: 0">Persons in titel 9</h2>
#
# <div class="entities" style="line-height: 2.5">Exclusive: Myanmar's delaying tactics blocking
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Rohingya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  return - Bangladesh PM</div>

# %%
colors = { 'PERSON':'red'}
options = {'ents': [ 'PERSON'], 'colors': colors}
for i in range(0, 2):
    body = df.iloc[i]['Body']
    doc = nlp(body)
    doc.user_data['title'] = 'Persons in text ' + str(i)
    displacy.render(doc, style='ent', jupyter=True, options=options)
# Out:
# <h2 style="margin: 0">Persons in text 0</h2>
#
# <div class="entities" style="line-height: 2.5">As few as 630 UK-based finance jobs have been shifted or created overseas with just six months to go before Brexit, a far lower total than banks said could move after Britain’s surprise vote to leave the European Union, according to a new Reuters survey. Many bankers and politicians predicted after the June 2016 referendum that leaving the EU would prompt a mass exodus of jobs and business and deal a crippling blow to London’s position in global finance. But as Brexit Day nears, the number of jobs that UK-based financial institutions say they expect to move in the event of a “hard” Brexit was around 5,800, just 500 more than the last survey in March, and with more firms responding. That compares to around 10,000 in the first survey in September 2017. The results are based on answers from 134 of the biggest or most internationally-focused banks, insurers, asset managers, private equity firms and exchanges to a survey conducted by between Aug. 1 and Sept. 15. Nearly all of those surveyed said they are moving as few people as possible, hoping for a last-minute political deal that protects access to the EU’s $19.7 trillion-a-year economy after Britain leaves the bloc.  The likelihood of a “hard” or “no-deal” Brexit has increased substantially since Prime Minister
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Theresa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  May’s plan for maintaining ties with the EU has been rejected by Brussels as well as by many politicians in her own Conservative Party. Many business chiefs fear Britain could be heading for a chaotic split that would spook financial markets and dislocate trade flows across Europe and beyond. Some politicians on both sides put the odds of talks collapsing at more than 50 percent. The survey findings suggest London, which has been a critical artery for the flow of money around the world for centuries, is likely to remain the world’s largest center of international finance. While New York is by some measures bigger, it is more centered on American markets, while London focuses on international trade.
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Verwandte ThemenFactbox
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            if ent.text in personenliste:
                personenliste[ent.text] += 1
            else:
                personenliste[ent.text] = 1

# %%
personenliste
# Out:
# {'Theresa': 4,
#  'Verwandte ThemenFactbox': 1,
#  'Bruegel': 2,
#  'Iain Anderson': 1,
#  'Anderson': 1,
#  'Exclusive BRITAIN': 1,
#  'Richard Small': 1,
#  'Addleshaw Goddard': 1,
#  'Jobs': 1,
#  'Theresa May': 14,
#  'Henry NichollsIf': 1,
#  'Keir Starmer': 3,
#  'Boris Johnson': 1,
#  'May': 3,
#  'Bill Cosby': 6,
#  'Cosby': 42,
#  'Andrea Constand': 3,
#  'Steven': 3,
#  'Chelan Lasha': 1,
#  'Cliff Huxtable': 1,
#  '” Kevin Steele': 1,
#  'Andrew Wyatt': 1,
#  'Amy Worden': 1,
#  'Worden': 1,
#  'Randy Akers': 1,
#  'Sam Hodge': 1,
#  'Marlen Squire': 1,
#  'Sgt': 1,
#  'Jorge Intriago': 1,
#  'Jackie Broach-Akers': 2,
#  'Slideshow': 14,
#  'Erdogan': 15,
#  'Tayyip Erdogan': 1,
#  'Mike Pompeo': 9,
#  'Andrew Brunson': 1,
#  'Donald Trump': 149,
#  'Brunson': 1,
#  'Angela Merkel': 3,
#  'Bashar al-Assad': 3,
#  'Elon Musk’s': 1,
#  'Joe Skipper': 1,
#  'Yusaku Maezawa': 1,
#  'Ispace': 1,
#  'Lucy Nicholson': 2,
#  'Brian Hook': 1,
#  'Sheikh Hasina': 2,
#  'Bangladesh': 2,
#  'Aung San Suu Kyi': 3,
#  'Hasina': 1,
#  'Zaw Htay': 2,
#  'Bazaar': 1,
#  'Clodagh': 1,
#  'Bhasan Char': 1,
#  'Rakhine': 1,
#  'Khaleda Zia': 1,
#  'Hassan Rouhani': 22,
#  '\xa0': 9,
#  'Twitter': 14,
#  'Carlo AllegriThe': 1,
#  'Mark': 2,
#  'Jeffress': 1,
#  'Rush Limbaugh': 1,
#  'Kavanaugh': 201,
#  'Trump': 59,
#  'Brett Kavanaugh': 61,
#  '     ': 1,
#  'Phil Bredesen': 2,
#  'Mark Blinch': 1,
#  'Marsha Blackburn': 2,
#  'Bredesen': 9,
#  'Bob Corker': 2,
#  'Blackburn': 7,
#  'Chuck Schumer': 3,
#  'Hillary Clinton': 6,
#  'Barack Obama': 8,
#  'Schumer': 1,
#  'Vox Populi Polling': 1,
#  'Kim Jong Un': 9,
#  'Mike Segar/File Photo': 1,
#  'Christine Blasey Ford': 16,
#  'Rachel Mitchell': 1,
#  'Kamala Harris': 2,
#  'Blasey Ford': 1,
#  'Harris': 1,
#  'Deborah Ramirez': 4,
#  'Verwandte ThemenMcConnell': 1,
#  'Mitch McConnell': 9,
#  'Ramirez': 6,
#  'John Clune': 1,
#  'Debbie': 1,
#  'Alex Wroblewski': 8,
#  'Lisa Murkowski': 3,
#  'Susan Collins': 3,
#  'Jeff Flake': 2,
#  'Murkowski': 2,
#  'McConnell': 8,
#  'Kavanaugh qualified?’': 1,
#  'Dick Durbin': 1,
#  'Soroush': 1,
#  'Verwandte': 4,
#  'Indian Oil': 1,
#  'Ricacorp Properties': 1,
#  'Alicia Garcia-Herrero': 1,
#  ' ': 1,
#  'Bobby': 1,
#  'Sun Hung Kai’s': 1,
#  'Victor Lui': 1,
#  'Quincy Chow': 1,
#  'Sharmaine Lau': 1,
#  'David': 1,
#  'AI': 2,
#  'Kim Kyung-HoonSpreadbetters': 1,
#  'Akira Takei': 1,
#  'Tatsufumi Okoshi': 1,
#  'Alex Bernhardt Jr.': 1,
#  'Audio': 1,
#  'Win Cramer': 1,
#  'Cramer': 1,
#  '6301.T': 1,
#  'Mid-Continental Nail': 1,
#  'Kelly Craver': 1,
#  'Mohawk Industries': 1,
#  'Craver': 1,
#  'Jerome Powell': 4,
#  'Joseph Lavorgna': 1,
#  'Thomas Julien': 1,
#  'Powell': 7,
#  'Jan Hatzius': 1,
#  'Wang Yi': 2,
#  'Santo Domingo': 2,
#  'Ricardo RojasBeijing': 1,
#  'Henry Kissinger': 1,
#  'Councillor Wang Yi': 3,
#  'Wang': 6,
#  'Nicolas Maduro': 5,
#  'Delcy Rodriguez': 2,
#  'Vladimir Padrino': 1,
#  'Maduro': 1,
#  'Marco Bello': 1,
#  'Raul Gallegos': 1,
#  'Mike Pence': 2,
#  'Cilia Flores': 1,
#  'Vladimir Padrino Lopez': 1,
#  'Carlos Jasso': 1,
#  'Diosdado Cabello': 1,
#  'Francis': 14,
#  'Max RossiIn': 1,
#  'Cardinal Joseph Zen': 1,
#  'Verwandte ThemenPope': 1,
#  'Moon Jae-in': 5,
#  'Carlos BarriaThe': 1,
#  'Signing Ceremony': 1,
#  'Rod Rosenstein': 17,
#  'Rosenstein': 20,
#  'Sarah Sanders': 2,
#  'Rod': 2,
#  'Rosenstein?Instant View': 1,
#  'Robert Mueller': 3,
#  'Chris WattieIf': 1,
#  'John Kelly': 2,
#  'Jeff Sessions': 4,
#  'Sessions': 5,
#  'Andrew McCabe': 2,
#  'Robert) Mueller': 2,
#  'McCabe': 6,
#  'Sally Yates': 1,
#  "Robert Mueller's": 1,
#  'Mueller': 3,
#  'DOJ': 1,
#  'Max RossiBut': 1,
#  'Najib': 4,
#  'Najib Razak': 3,
#  'Lai Seng SinHer': 1,
#  'Development Berhad': 1,
#  'Rosmah Mansor': 1,
#  'Lai Seng SinRosmah': 1,
#  'Hermes Birkin': 1,
#  'Mahathir Mohamad': 1,
#  'Imelda Marcos': 1,
#  'Ferdinand Marcos': 1,
#  'John Guy': 1,
#  'Jeff Auxier': 1,
#  'Colin Kaepernick': 2,
#  'Adidas AG': 1,
#  'DE': 2,
#  'Armour': 1,
#  'Andrew Campion': 1,
#  'Jessica Ramirez': 1,
#  'Richard Parsons': 3,
#  'Sumner Redstone': 1,
#  'Leslie Moonves': 1,
#  'Bruce Gordon': 1,
#  'William Cohen': 1,
#  'Robert Lighthizer': 4,
#  'Adam Austen': 1,
#  'Eduardo Sanchez': 1,
#  'Enrique Pena Nieto': 4,
#  'Justin Trudeau': 5,
#  'Edgard Garrido': 1,
#  'Trudeau': 5,
#  'Lighthizer': 1,
#  'Jared Kushner': 3,
#  'John Bolton': 6,
#  'Kevin Lamarque': 5,
#  'Andrey Bugera': 1,
#  'Vladimir Lenin': 1,
#  'Eduard KorniyenkoBut': 1,
#  'Vladimir Putin': 8,
#  'Vorkuta': 7,
#  'Bugera': 2,
#  'Vologda': 1,
#  'Putin': 5,
#  'Sergei': 1,
#  'Alexander Golyanchuk': 1,
#  'Olga Lebedeva': 1,
#  'Rouhani': 27,
#  'Verwandte ThemenBolton': 1,
#  'Emmanuel Macron': 3,
#  'Macron': 3,
#  'Caitlin OchsTrump': 1,
#  'Kim': 23,
#  'Anwar Gargash': 4,
#  'Gargash': 1,
#  'Arnd WIegmann/File': 1,
#  'Keith Enright': 1,
#  'Google Buzz': 1,
#  'John Thune': 5,
#  'Andrew DeVore': 1,
#  'Damien Kieran': 1,
#  'individuals’': 1,
#  'Jerry Brown': 2,
#  'Bolton': 11,
#  'Eric ThayerSpeaking': 1,
#  'Joshua Roberts': 8,
#  "Brett Kavanaugh's": 1,
#  'Tiger Woods': 5,
#  'Mike SegarThe': 2,
#  'Abe': 7,
#  'Shinzo Abe': 3,
#  'Moon': 13,
#  'Xi Jinping': 2,
#  'Trump-Kim': 2,
#  'Ri Yong Ho': 2,
#  'Ri': 1,
#  'Yonhap': 1,
#  'Mike Dowdall': 1,
#  'Richard Robinson': 1,
#  'Wang Shouwen': 3,
#  'Mario Draghi': 2,
#  'Eric Theoret': 1,
#  'XAU=': 1,
#  '        ': 1,
#  'DPRK': 1,
#  'Robert Abrams': 2,
#  'Abrams': 4,
#  'Mattis': 9,
#  'Verwandte ThemenMajor': 1,
#  'Chris Wattie': 5,
#  'Roy Blunt': 1,
#  'John Barrasso': 1,
#  'John Cornyn': 3,
#  'Al Drago': 1,
#  'Beni': 6,
#  'Peter Salama': 1,
#  'Oicha': 1,
#  'Michael Kors': 15,
#  'Versace': 24,
#  'Jimmy Choo': 2,
#  'John Idol': 1,
#  'Verwandte ThemenVersace': 1,
#  'Donatella Versace': 3,
#  'Jonathan Akeroyd': 2,
#  'Louis Vuitton-owner': 1,
#  'Giuliano Noci': 2,
#  'Bottega Veneta': 2,
#  'Brioni': 1,
#  'Matteo Salvini': 1,
#  'Michael Kors’': 2,
#  'Leonhard FoegerThe': 1,
#  'Louis Vuitton': 3,
#  'Kors': 1,
#  'Hermes': 1,
#  'Moncler': 1,
#  'Marc Jacobs': 1,
#  'Burberry': 1,
#  'BRBY.L': 1,
#  'Flavio Cereda': 1,
#  'Jefferies': 2,
#  'Lanvin': 1,
#  'Kate Spade': 2,
#  'Ludovic Grandchamp of Savigny Partners': 1,
#  'Qualcomm': 31,
#  'Mike Blake/File': 1,
#  'Jacqueline Stern': 1,
#  'Edgar Su': 1,
#  'Josh Hawley': 1,
#  'Ford': 20,
#  'Allies’': 1,
#  'Feinstein': 11,
#  'MIA Recognition Day': 1,
#  'Cruz': 32,
#  'Ted Cruz': 6,
#  "Beto O'Rourke": 3,
#  'Nathan Hunsinger': 2,
#  'Tom Fox': 1,
#  'Emily Miller': 2,
#  'Verwandte ThemenFull-blown': 1,
#  'Stephen Schwarzman': 1,
#  'Ajay Banga': 1,
#  'Luo Wen': 1,
#  'Luo': 1,
#  'Roberto Azevedo': 2,
#  'Sergio MoraesSpeaking': 1,
#  'Azevedo': 3,
#  'Buenos Aires': 5,
#  'Hannah': 2,
#  'Lewis': 1,
#  'Richard Clifton': 1,
#  'Shannon Liss-Riordan': 1,
#  'Dara Khosrowshahi': 1,
#  'Khosrowshahi': 1,
#  'Kevin Systrom': 4,
#  'Mike Krieger': 3,
#  'Mark Zuckerberg': 3,
#  'Scott Kessler': 1,
#  'Jan Koum': 2,
#  'Brian Acton': 2,
#  'Bloomberg': 5,
#  'Systrom': 8,
#  'Krieger': 5,
#  'Zuckerberg': 10,
#  'Jonas Kron': 1,
#  'Lindsey Graham': 4,
#  'Rocky Mountains': 1,
#  'Ryan Moehring': 2,
#  'REUTERS“It': 1,
#  'David Lucas': 1,
#  'Tom Koerner': 1,
#  'Philip Brimmer': 1,
#  '” Randall Weiner': 1,
#  'Weiner': 1,
#  'Lindsay Masters': 1,
#  'Rocky Flat’s': 1,
#  'Brimmer': 1,
#  'Narendra Modi': 1,
#  'Rick Wilking': 2,
#  'Chris Rupkey': 1,
#  ' Roiana Reid': 1,
#  'CoreLogic Case-Shiller': 1,
#  'Joel Naroff': 1,
#  'Lucia Mutikani': 1,
#  'Starmer': 2,
#  "Verwandte ThemenBritain's": 1,
#  'Jeremy Corbyn': 5,
#  'Phil Noble“That’s': 1,
#  'Corbyn': 6,
#  'Brendan Chilton': 1,
#  'John McDonnell': 2,
#  'Jeff Mason': 1,
#  'Christine Blasey Ford’s': 3,
#  'Donald Trump Jr.': 1,
#  'Collins': 4,
#  'Neil Gorsuch': 2,
#  'Dean Heller': 1,
#  'Heller': 3,
#  'Rand Paul': 1,
#  'Paul': 1,
#  'Ben Sasse': 1,
#  'Heidi Heitkamp': 1,
#  'Joe Manchin': 1,
#  'Obamacare': 1,
#  'Manchin': 1,
#  'Joe Donnelly': 1,
#  'Doug Jones': 1,
#  'Jon Tester': 1,
#  'Gorsuch': 2,
#  'Bill Nelson': 2,
#  'Nelson': 2,
#  'Richard Cowan': 1,
#  'Amanda Becker': 2,
#  'Lawrence Hurley': 1,
#  'Stephen Biegun': 1,
#  'Heather Nauert': 1,
#  'Andrew Macdonald': 1,
#  'Macdonald': 5,
#  'Juan Carlos': 1,
#  'Marcos Brindicci“It’s': 1,
#  'Hernan Letcher': 1,
#  'Images)“It': 1,
#  'Bumble': 1,
#  'Taru Kapoor': 1,
#  'Bengaluru': 1,
#  'App Annie': 1,
#  'Robert B. Abrams': 1,
#  'Mark C. Olsen': 1,
#  'Craig Faller': 1,
#  'Claire McCaskill': 3,
#  'David Redl': 1,
#  'terrorists’': 1,
#  'Haley': 6,
#  'Nikki Haley': 3,
#  'Rudy Giuliani': 6,
#  'Ayatollah Ali Khamenei': 11,
#  'Carlo AllegriTrump': 1,
#  'Debra Katz': 4,
#  'Chuck Grassley': 9,
#  'Katz': 9,
#  'Mazie Hirono': 1,
#  'Bridgit Mendler': 1,
#  'Chrissy': 2,
#  'Arnd WIegmann': 1,
#  'Brian Snyder': 4,
#  'Border': 2,
#  'Obama': 3,
#  'David Perdue': 1,
#  'Bill': 3,
#  'Law Enforcement': 2,
#  'Jay': 1,
#  '@AbeShinzo': 1,
#  'Charles H. McDaniel': 1,
#  'William H. Jones': 1,
#  'Mark Blinch Gottlieb': 1,
#  'Koum': 1,
#  'Chris Cox': 1,
#  'Stephen Chernin': 1,
#  'Bryce Xavier': 1,
#  'Lele Pons': 1,
#  'David Ingram': 1,
#  'Michael Bromwich': 2,
#  'Christine Ford': 1,
#  'Dianne Feinstein': 6,
#  'Jim Bourg': 1,
#  'Bodo': 5,
#  'Aaron Sayne': 1,
#  'SPILLS  ': 1,
#  'Ken Saro-Wiwa': 2,
#  'Ron BoussoDozens': 1,
#  'Ogonnaya Iroakasi': 1,
#  'Daniel Leader': 1,
#  'Michael Porobunu': 1,
#  '” Bayo Ojulari': 1,
#  'Ali Akbar Velayati': 3,
#  "Ayatollah Ali Khamenei's": 1,
#  'Tammam Salam': 1,
#  'Mohamed Azakir': 1,
#  'Ayatollah Khamenei': 2,
#  'Verwandte ThemenTrump': 2,
#  'Khamenei': 12,
#  'Miryousefi': 1,
#  'Jim Urquhart': 2,
#  'Dana Christensen': 1,
#  'Christensen': 2,
#  'Matt Mead': 1,
#  'Thomas White Facebook': 1,
#  'Korey Nelson': 1,
#  'Selena Scola': 1,
#  'Bertie Thomson': 1,
#  'CIV0513': 1,
#  'Stormy Daniels': 1,
#  'Daniels': 3,
#  'Mike Blake/File PhotoDaniels': 1,
#  'Stephanie Clifford': 2,
#  'James Otero': 1,
#  'Otero': 5,
#  'Michael Avenatti': 2,
#  'Michael Cohen': 2,
#  'Andrew Cullen': 1,
#  'Andres Manuel Lopez Obrador': 2,
#  'Kevin LamarqueLopez Obrador': 1,
#  'Hector Vasconcelos': 1,
#  'Lopez Obrador’s': 4,
#  'Lopez Obrador': 6,
#  'Pena Nieto’s': 2,
#  'Pena Nieto': 3,
#  'Moises Kalach': 1,
#  'David MacNaughton': 1,
#  'Chrystia Freeland': 4,
#  'Violeta Schmidt': 1,
#  'Jerry Dias': 1,
#  'Kalach': 2,
#  'Luis Videgaray': 1,
#  'Jesus Seade': 1,
#  'Videgaray': 2,
#  'Seade': 1,
#  'Kushner': 1,
#  'Gustavo de Hoyos': 1,
#  'Dias': 1,
#  'Brian': 2,
#  'Peter Ferrara': 1,
#  'Reagan': 1,
#  "Donald J. Trump's": 1,
#  'Jason Chaffetz': 1,
#  'Nellie Liang': 1,
#  'Liang': 4,
#  'McCaskill': 1,
#  'Kirstjen Nielsen': 1,
#  'Resources Needed': 1,
#  'Erin Schaff': 1,
#  'Mike Segar“Despite': 1,
#  'Vehicle': 1,
#  'Verwandte ThemenTop': 1,
#  'Federica Mogherini': 2,
#  'Phil NobleAt': 1,
#  '” Merkel': 1,
#  'Dieter Kempf': 2,
#  'CMCSA.O': 4,
#  'Lucas Jackson': 2,
#  'Rupert Murdoch’s': 4,
#  'Murdoch': 9,
#  'Fox': 3,
#  'Heiko Maas': 3,
#  'Umit Bektas“If': 1,
#  'Aly Song': 1,
#  'Fu Ziying': 1,
#  'Fu': 1,
#  'Paul Manafort': 4,
#  'Special Counsel Robert Mueller’s': 2,
#  'Yuri Gripas': 3,
#  'Grassley': 8,
#  'Cornyn': 4,
#  'DEATH THREATS’ Ford': 1,
#  'Lisa Banks': 4,
#  'Mark Judge': 4,
#  'Brett': 2,
#  'Richard Blumenthal': 2,
#  'Clarence': 3,
#  'Anita Hill': 3,
#  'Thomas': 2,
#  'Tun Tun Nyi': 1,
#  'Sarah Margon': 1,
#  'Rohingya Muslims': 1,
#  'Min Aung Hlaing': 6,
#  'Matt Spetalnick': 1,
#  'Jason Szep': 1,
#  'Special Counsel Robert Mueller': 1,
#  'James Comey': 1,
#  'Jesse Panuccio': 1,
#  'Noel Francisco': 1,
#  'Jones Day': 1,
#  'Steven Engel': 1,
#  'Kevin Johnson': 1,
#  'David Ryder“There': 1,
#  'Johnson': 1,
#  'Howard Schultz': 1,
#  'Parisa Hafezi': 2,
#  'John Irish': 2,
#  'Michelle Nichols': 1,
#  'Arshad Mohammed': 2,
#  'Bill Cosby’s': 2,
#  'Gianna': 1,
#  'Kristen Dudley': 1,
#  'Janice Dickinson': 1,
#  'Steven Chanenson': 1,
#  'Amber Guyger': 2,
#  'Renee Hall': 1,
#  'Hall': 1,
#  'Guyger': 4,
#  'Botham Jean': 1,
#  'Mike Rawlings': 1,
#  'Jean': 4,
#  'Saint Lucia': 1,
#  'S. Lee Merritt': 1,
#  'Faith Johnson': 1,
#  'Richard Liu': 2,
#  'Liu': 25,
#  'Wil Florin': 1,
#  'Jill Brisbois': 1,
#  'Loretta Chao': 1,
#  'Mr. Liu': 1,
#  'Liu Qiangdong': 1,
#  'Zhang Zetian': 1,
#  'Qiang Dong Liu': 1,
#  'WeChat': 1,
#  '” Loretta Chao': 1,
#  'Andrzej Duda': 2,
#  'Duda': 3,
#  'Jim Mattis': 4,
#  'James Mattis': 2,
#  'Bob Woodward': 1,
#  'Mira Ricardel': 1,
#  'INSIDE': 1,
#  'Woodward': 1,
#  'Hugh Hewitt': 2,
#  'Chris WattieDemocrats': 1,
#  'Taylor Foy': 2,
#  'Anthony Kennedy': 3,
#  'Sel Hemingway': 1,
#  'Roy Cooper': 1,
#  'Dylan Lee': 1,
#  'Alexei Navalny': 5,
#  'Verwandte ThemenRussian': 1,
#  'Navalny': 3,
#  'Maxim ShemetovThe': 1,
#  'Jack Taylor': 2,
#  'Barrick Gold': 1,
#  'Barrick': 10,
#  'John Thornton': 1,
#  'Mark Bristow': 2,
#  'Graham Shuttleworth': 1,
#  'Thornton': 1,
#  'John Ing': 1,
#  'Russ Mould': 1,
#  'Bristow': 1,
#  'CIBC': 1,
#  'Barclays': 1,
#  'Thierry Gouegnon': 1,
#  'Chris Zaccarelli': 2,
#  'Brendan McDermidThe': 1,
#  'Hossein Salami': 1,
#  'Salami': 1,
#  '” Ali Shamkhani': 1,
#  'NEWS Mattis': 1,
#  'Mahmoud Alavi': 1,
#  'Karim Dahimi': 1,
#  'Scott Brown': 1,
#  'Raymond James': 1,
#  'Liu He': 1,
#  'Aly Song/File PhotoNews': 1,
#  'Rob Carnell': 1,
#  'Maxim ShemetovNavalny': 1,
#  'Graham': 2,
#  'Alex WroblewskiELECTIONS LOOM Ford': 1,
#  'Without Kennedy': 1,
#  'Cohn': 15,
#  'Gary Cohn': 2,
#  'Jamie Dimon': 3,
#  'Calling Dimon': 1,
#  'Jamie': 1,
#  'Dick Fuld': 2,
#  'Elizabeth Warren': 2,
#  'Dodd': 1,
#  'Mariano Rajoy': 1,
#  'Mike Segar': 1,
#  'KORS.N': 1,
#  'Luca Solca': 1,
#  'Gianni': 1,
#  'Allegra Versace Beck': 1,
#  'Carlos Barria“We’ll': 1,
#  'Ibrahim Mohamed Solih': 1,
#  'Mohamed Nasheed': 2,
#  'Nasheed': 7,
#  'Colombo': 1,
#  'Maumoon Abdul Gayoom': 2,
#  'Gayoom': 5,
#  'Miguel Diaz-Canel': 2,
#  'Desmond Boylan': 1,
#  'Raul Castro': 1,
#  'Bill de Blasio': 1,
#  'Foy': 1,
#  'ISSUES Ford': 1,
#  'Chris WattieRosenstein': 1,
#  'Thune': 1,
#  'John Kennedy': 2,
#  'Chris WattieBoth': 1,
#  'Kennedy': 2,
#  'Ann Wang': 1,
#  'File PhotoIn': 1,
#  'Jean-Claude Juncker': 1,
#  'Nicolas Veron': 1,
#  'mid-October': 1,
#  'Sanam Vakil': 1,
#  'Comcast': 2,
#  'Brian Roberts': 2,
#  'Netflix': 6,
#  'Grab': 1,
#  'Walter Theseira': 1,
#  'Jerry Lim': 1,
#  'Siri': 5,
#  'Accenture': 1,
#  'Tim Cook': 1,
#  'Marriot': 1,
#  'Marc Benioff': 1,
#  'Tim': 1,
#  'Benioff': 2,
#  'Cook': 2,
#  'Damir Sagolj': 1,
#  'Netgear': 1,
#  'Jim Brennan': 1,
#  'Brennan': 1,
#  'Izzy Santa': 1,
#  'Abdulla Yameen': 3,
#  'Qasim Ibrahim’s': 1,
#  'Qasim Ibrahim': 1,
#  'Majlis': 1,
#  'Kellyanne Conway': 1,
#  'John F. Kennedy': 1,
#  'JFK': 4,
#  'Christopher Lau': 1,
#  'Lau': 2,
#  'Christopher Avila': 1,
#  'Jack': 1,
#  'Jill KitchenerONLINE': 1,
#  'Anthony Bucci': 1,
#  'Walter Rivera': 1,
#  'Ali Shamkhani': 1,
#  'Fredrik Ivarsson': 1,
#  'Ivarsson': 2,
#  'Saipa Diesel': 3,
#  'Volvo': 1,
#  'Andy Chan': 2,
#  'Paul Yeung': 1,
#  'John Lee': 1,
#  'Lee': 5,
#  'Chan': 1,
#  'Xi Xinping': 1,
#  'Greg Torode': 1,
#  'Clare Jim': 1,
#  'Andrew MacAskill': 1,
#  'Michael Holden': 1,
#  'Abdel Fattah al-Sisi': 1,
#  'Vassily Nebenzia': 1,
#  'Darren Ornitz': 1,
#  'Khalid al-Falih': 1,
#  'Falih': 4,
#  'Verwandte ThemenIran': 1,
#  'Bijan Zanganeh': 1,
#  'Alexander Novak': 2,
#  'Hossein Kazempour Ardebili': 1,
#  'Kazempour': 2,
#  'Nancy Pelosi': 2,
#  'Pierre Lampron': 1,
#  'Rebecca Cook': 1,
#  'George Papadopoulos': 6,
#  'Samuel Patten': 1,
#  'Manafort': 1,
#  'Michael Flynn': 3,
#  'Flynn': 15,
#  'Rick Gates': 1,
#  'Alex Van der': 1,
#  'Zwaan': 5,
#  'Richard Pinedo': 1,
#  'Pinedo': 2,
#  'Konstantin Kilimnik': 1,
#  'Frances Kerry': 1,
#  'Cynthia Osterman': 1,
#  'Mohammad Zargham': 1,
#  'Susan Heavey': 1,
#  'Grant McCool': 1,
#  'Victorious Cuomo': 1,
#  'Andrew Cuomo': 4,
#  'Cynthia Nixon': 2,
#  'Patrick Egan': 1,
#  'Nixon': 2,
#  'Kathy Hochul': 1,
#  'Cynthia': 1,
#  'Mindy Rosier': 1,
#  'Grant Reeher': 1,
#  'Andrea Stewart-Cousins': 1,
#  'Daniel Lewis': 1,
#  '” Mahmoud Alavi': 1,
#  'Jack Ablin': 1,
#  'Ablin': 1,
#  'Zoltan Pozsar': 1,
#  'Oliver Pursche': 1,
#  'reut.rs/2PY8MNx': 1,
#  'David Lafferty': 1,
#  'Brendan McDermid': 2,
#  'Steve Chiavarone': 1,
#  'Netflix Inc': 3,
#  'Cliff Hodge': 1,
#  'Jeffrey Liguori': 1,
#  'Robert Lighthizer - the': 1,
#  'Pedro Sanchez': 1,
#  'Kevin LamarqueHe': 1,
#  'Toshimitsu Motegi': 1,
#  'Robert Lighthizer -': 1,
#  'Cody Wilson': 1,
#  'Samy Khalil': 1,
#  'Cody': 1,
#  'Rupert Murdoch': 1,
#  'Brian L. Roberts': 1,
#  'Amazon': 2,
#  'Richard Greenfield': 1,
#  'BTIG': 1,
#  'Greenfield': 1,
#  'Alice Enders': 1,
#  'Enders Analysis': 1,
#  'Sam Snead’s': 1,
#  'Erica Herman': 1,
#  'Mark Steinberg': 1,
#  'Verwandte ThemenTimeline': 1,
#  'Rory McIlroy': 1,
#  'Justin Rose': 1,
#  'Rose': 1,
#  'Billy Horschel': 1,
#  'Butch Dill-USA': 1,
#  'Had Rose': 1,
#  'Jack Nicklaus': 3,
#  'Earl': 1,
#  'Pops': 1,
#  'Christopher Hanewinckel-USA': 3,
#  'Nicklaus': 1,
#  'Tiger': 2,
#  'Peter Strzok': 1,
#  'Lisa Page': 1,
#  'Debbie Stabenow': 1,
#  'John Kerry': 1,
#  'Carrie Severino': 1,
#  'George W. Bush': 3,
#  'Bush': 2,
#  'Hogan Gidley': 1,
#  'Ryan': 1,
#  'Ricardo Rossello': 1,
#  'Maria': 2,
#  'bit.ly/2wwqEqF': 1,
#  'Jonathan Ernst': 1,
#  'Paul Ryan': 1,
#  'Marco Rubio': 1,
#  'Rick Scott': 1,
#  'Lares': 1,
#  'Tiger Woods’': 1,
#  'Sam Snead': 2,
#  'Ben Hogan': 1,
#  'Arnold Palmer': 1,
#  'Andrew Both': 2,
#  'Pritha Sarkar': 2,
#  'Frank Pingue': 1,
#  'Charlie Rose': 1,
#  'Aviva Orenstein': 1,
#  'Harvey Weinstein': 1,
#  'Deborah Tuerkheimer': 1,
#  'Tuerkheimer': 1,
#  'RAINN': 1,
#  'Mark Makela': 1,
#  'Ivan Cajic': 1,
#  'Ken Polcari': 1,
#  'Steven DeSanctis': 1,
#  'Vilnius': 2,
#  'Golgotha': 1,
#  'Sigitas Tamkevicius': 1,
#  'John Magufuli': 1,
#  'Charles Ngarima': 1,
#  'Jennifer Idhoze': 1,
#  'Isack Kamwelwe': 1,
#  'Ukerewe': 1,
#  'Neil HallThe': 1,
#  'Jeenah MoonBefore': 1,
#  'Giuliani': 9,
#  'Randy Capps': 1,
#  'Jeffrey Passel': 1,
#  'Tom MacArthur': 2,
#  'Aaron P.': 1,
#  'Andy Kim': 1,
#  'Darrell Issa': 1,
#  'Gina Raimondo': 4,
#  'Michelle Obama': 1,
#  'Matt Brown': 1,
#  'Raimondo': 1,
#  'Allan Fung': 1,
#  'Cranston': 1,
#  'Joseph Trillo': 1,
#  'Ocasio-Cortez': 2,
#  'Ayanna Pressley': 1,
#  'Brown': 1,
#  'Brian Sandoval': 1,
#  'Terry McAuliffe': 1,
#  'John Williams': 1,
#  'Janet Yellen': 1,
#  'Lael Brainard': 1,
#  'Charles Evans': 1,
#  'Eric Rosengren': 1,
#  'Yellen': 1,
#  'Kathy Bostjancic': 1,
#  'Mary F. Calvert/File Photo': 1,
#  'Ayatollah Ruhollah Khomeini': 2,
#  'Baluch': 1,
#  'ReutersAt': 1,
#  '” Nicky Morgan': 1,
#  'boardsUK': 1,
#  'Tom Watson': 2,
#  'Watson': 1,
#  'Insight NIGERIA-SECURITY': 1,
#  'Ron BoussoFollowing': 1,
#  'Sani Abacha’s': 1,
#  'Claudio Descalzi': 1,
#  'Brett Kavanaugh’s': 2,
#  '” Debra Katz': 2,
#  'Orrin Hatch': 1,
#  'Kupec': 1,
#  'Mike SegarConfirming Kavanaugh': 1,
#  'Antonio Guterres': 2,
#  '” Guterres': 1,
#  'Aung San Suu Kyi’s': 1,
#  'Wa Lone': 2,
#  'Madoka Ikegami': 1,
#  'Suu Kyi': 3,
#  'Jeremy Hunt': 3,
#  'Hunt': 4,
#  'Burma': 1,
#  'Eric Holder': 1,
#  'John Murtha Johnstown-Cambria County Airport': 1,
#  'Kevin': 1,
#  'Hillary': 1,
#  'Rudy': 1,
#  'Heed': 1,
#  'Chris Pappas': 3,
#  'Brian SnyderFormer': 1,
#  'Carol Shea-Porter': 1,
#  'Eddie Edwards': 1,
#  'Andy Sanborn': 1,
#  'Maura Sullivan': 1,
#  'Voter': 1,
#  'Levi Sanders': 1,
#  'Bernie Sanders': 2,
#  'Molly Kelly': 1,
#  'Chris Sununu': 1,
#  'Congresswoman Ann Kuster': 1,
#  'Yongbyon': 3,
#  'Dismantling Yongbyon': 1,
#  'Joshua Pollack': 1,
#  'Jenny Town': 1,
#  'TONGCHANG-RI': 1,
#  'Sohae': 1,
#  'North': 2,
#  'Tonghae': 1,
#  'Lee Ho-ryung': 1,
#  'Kim Dae-young': 1,
#  'Verwandte ThemenFox': 1,
#  'Martin Gilbert': 1,
#  'James': 1,
#  'Jeremy Darroch': 1,
#  'Carrie Lam': 1,
#  'Leung': 1,
#  'Feng Yan': 1,
#  'Zheng Zeguang': 1,
#  'Terry Branstad': 1,
#  'Shen Jinlong': 1,
#  'Wu Qian': 1,
#  'Rosoboronexport': 1,
#  'Li Shangfu': 1,
#  'Wu': 1,
#  'Joseph Tanner': 1,
#  'L.V. Sutton': 1,
#  'Bahram Qasemi': 2,
#  'Hamid Farahvashian': 1,
#  'Ali Alfoneh': 1,
#  'Garrett Marquis': 1,
#  'Rudolph Giuliani': 2,
#  'Amr Alfiky“I': 1,
#  'Leah Millis/File Photo': 1,
#  'Nathalie Loiseau': 1,
#  'Michael Roth': 1,
#  'Jeremy Hosking': 1,
#  'Verwandte ThemenIrish': 1,
#  '” David Davis': 1,
#  'Donald Tusk': 1,
#  'Simon Coveney': 3,
#  'David Cheskin': 1,
#  'Christian Mang': 1,
#  'Kevin Brady': 2,
#  'John Gimigliano': 1,
#  'KPMG LLP': 1,
#  'Matt Gorman': 1,
#  'Jobs Act': 1,
#  'Saeb Erekat': 1,
#  'Walid Nammour': 1,
#  'Mike SegarK.T.': 1,
#  'Kislyak': 2,
#  'Robert Giuffra': 1,
#  'Dado Ruvic': 1,
#  'Garrett Ventry': 1,
#  'Ventry': 1,
#  'John Bell': 1,
#  'Mohammed bin Hamad Al-Rumhy': 1,
#  "O'Rourke": 1,
#  'Robert Francis': 1,
#  'Loren Elliott': 1,
#  'File Photos': 1,
#  'Mohammed Javad Zarif': 1,
#  'Der Spiegel': 1,
#  'Caren Firouz/File Photo': 1,
#  'Sioux Falls': 1,
#  'Sonny Perdue': 2,
#  'Perdue': 1,
#  'Cecilia Malmstrom': 1,
#  'Saint-Valerien-de-Milton': 2,
#  'Larry Kudlow': 1,
#  'José Isaías Barahona': 1,
#  'Marta Larra': 1,
#  'James Lawler': 1,
#  'David Dao': 1,
#  'Bill Shuster': 1,
#  'Peter DeFazio': 1,
#  'Roscosmos': 2,
#  '” Vladimir Ustimenko': 1,
#  'Crimea': 1,
#  'Soleimani': 1,
#  'CAPABILITIES': 1,
#  'Julian Assange': 3,
#  'Lenin Moreno': 1,
#  'Assange': 1,
#  'Vintimilla': 1,
#  'Moreno': 1,
#  'Peter Nicholls': 1,
#  'Maha El Dahan': 3,
#  'John Stonestreet': 2,
#  'Brian SnyderGunmen': 1,
#  'Ahmed Tolba': 1,
#  '” Yahya Rahim Safavi': 1,
#  'Yaghub Hur Totsari': 1,
#  ...}

# %% [markdown]
# ## Save countlist

# %%
import json
json = json.dumps(personenliste)
f = open("./data/personenliste_en.json","w")
f.write(json)
f.close()

# %% [markdown]
# ## Clean list

# %%
def cleandict_en(inputdict):
    
    dict2 = inputdict.copy()
    for key in inputdict.keys(): 
        if key.startswith("\\"):
            del dict2[key]
        if key.strip() == "":
            del dict2[key]
        if key.strip() == "Verwandte ThemenFactbox":
            del dict2[key]
        if key.strip() == "Sgt":
            del dict2[key]
        
    return dict2

# %%
personenclean = cleandict_en(personenliste)

# %% [markdown]
# ## Map personnames together (i.e. "Donald Trump" and "Trump")

# %%
def listekompakt(inputdict):
    outputdict = {}

    for name, num in inputdict.items():
        for key in inputdict.keys():            
            if (name == key):
                continue
            if (name in key) and (inputdict[name] > 5):
                inputdict[name] += num
                inputdict[key] = 0
                break
    for name, num  in inputdict.items():
        if num > 0:
            outputdict[name] = num
    return outputdict

# %%
personenkompakt = listekompakt(personenclean)

# %%
import json
json = json.dumps(personenkompakt)
f = open("./data/personenliste_en_clean.json","w")
f.write(json)
f.close()

# %% [markdown]
# ## Barchart of sortet counts

# %%
personen = sorted(personenkompakt.items(), key=itemgetter(1),reverse=True)

names = list(zip(*personen))[0][0:40]
values = list(zip(*personen))[1][0:40]
x_pos = np.arange(len(names)) 

plt.xticks(rotation='vertical')
plt.subplots_adjust(bottom=0.2)
plt.bar(x_pos, values)
plt.xticks(x_pos, names) 
plt.suptitle('Persons in the News')
plt.savefig('./images/hauefigkeit_news_en.png', dpi=300)
plt.show()

# %% [markdown]
# ## Build list of counts per day

# %%
datumliste={}

for i in range(0, len(df)):
    body = df.iloc[i]['Body']
    titel = df.iloc[i]['Titel']
    datum = df.iloc[i]['Datum']
    datum = datum.split(" ")[0]
    doc = doc = nlp(titel + "\n" + body)
    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            if ent.text in datumliste:
                if datum in datumliste[ent.text]:
                    datumliste[ent.text][datum] += 1
                else:
                    datumliste[ent.text][datum] = 1
            else:
                datumliste[ent.text] = {}
                datumliste[ent.text][datum] = 1

# %%
datumliste
# Out:
# {'Theresa': {'2018-09-23': 2, '2018-09-26': 2},
#  'Verwandte ThemenFactbox': {'2018-09-26': 1},
#  'Bruegel': {'2018-09-24': 1, '2018-09-26': 1},
#  'Iain Anderson': {'2018-09-26': 1},
#  'Anderson': {'2018-09-26': 1},
#  'Exclusive BRITAIN': {'2018-09-26': 1},
#  'Richard Small': {'2018-09-26': 1},
#  'Addleshaw Goddard': {'2018-09-26': 1},
#  'Jobs': {'2018-09-26': 1},
#  'Theresa May': {'2018-09-22': 3,
#   '2018-09-23': 2,
#   '2018-09-24': 3,
#   '2018-09-25': 5,
#   '2018-09-26': 1},
#  'Henry NichollsIf': {'2018-09-26': 1},
#  'Keir Starmer': {'2018-09-25': 2, '2018-09-26': 1},
#  'Boris Johnson': {'2018-09-26': 1},
#  'May': {'2018-09-25': 1, '2018-09-26': 2},
#  'Bill Cosby': {'2018-09-23': 1, '2018-09-24': 1, '2018-09-25': 4},
#  'Cosby': {'2018-09-23': 10, '2018-09-24': 14, '2018-09-25': 18},
#  'Andrea Constand': {'2018-09-23': 1, '2018-09-24': 1, '2018-09-25': 1},
#  'Steven': {'2018-09-23': 1, '2018-09-24': 1, '2018-09-25': 1},
#  'Chelan Lasha': {'2018-09-25': 1},
#  'Cliff Huxtable': {'2018-09-25': 1},
#  '” Kevin Steele': {'2018-09-25': 1},
#  'Andrew Wyatt': {'2018-09-25': 1},
#  'Amy Worden': {'2018-09-25': 1},
#  'Worden': {'2018-09-25': 1},
#  'Randy Akers': {'2018-09-25': 1},
#  'Jeffress': {'2018-09-26': 1},
#  'Rush Limbaugh': {'2018-09-26': 1},
#  'Kavanaugh': {'2018-09-07': 14,
#   '2018-09-13': 14,
#   '2018-09-16': 26,
#   '2018-09-17': 4,
#   '2018-09-18': 9,
#   '2018-09-19': 10,
#   '2018-09-20': 11,
#   '2018-09-21': 36,
#   '2018-09-22': 4,
#   '2018-09-23': 20,
#   '2018-09-24': 21,
#   '2018-09-25': 30,
#   '2018-09-26': 2},
#  'Trump': {'2018-09-07': 2,
#   '2018-09-08': 1,
#   '2018-09-10': 3,
#   '2018-09-13': 2,
#   '2018-09-14': 5,
#   '2018-09-16': 2,
#   '2018-09-18': 6,
#   '2018-09-21': 3,
#   '2018-09-22': 2,
#   '2018-09-23': 4,
#   '2018-09-24': 14,
#   '2018-09-25': 12,
#   '2018-09-26': 3},
#  'Brett Kavanaugh': {'2018-09-07': 3,
#   '2018-09-13': 2,
#   '2018-09-16': 4,
#   '2018-09-17': 9,
#   '2018-09-18': 4,
#   '2018-09-19': 5,
#   '2018-09-20': 2,
#   '2018-09-21': 7,
#   '2018-09-22': 4,
#   '2018-09-23': 3,
#   '2018-09-24': 9,
#   '2018-09-25': 7,
#   '2018-09-26': 2},
#  '     ': {'2018-09-26': 1},
#  'Phil Bredesen': {'2018-09-26': 2},
#  'Mark Blinch': {'2018-09-26': 1},
#  'Marsha Blackburn': {'2018-09-26': 2},
#  'Bredesen': {'2018-09-26': 9},
#  'Bob Corker': {'2018-09-21': 1, '2018-09-26': 1},
#  'Blackburn': {'2018-09-26': 7},
#  'Chuck Schumer': {'2018-09-18': 1, '2018-09-26': 2},
#  'Hillary Clinton': {'2018-09-07': 1,
#   '2018-09-11': 1,
#   '2018-09-14': 1,
#   '2018-09-21': 2,
#   '2018-09-26': 1},
#  'Barack Obama': {'2018-09-10': 1,
#   '2018-09-11': 1,
#   '2018-09-23': 1,
#   '2018-09-24': 2,
#   '2018-09-25': 2,
#   '2018-09-26': 1},
#  'Schumer': {'2018-09-26': 1},
#  'Vox Populi Polling': {'2018-09-26': 1},
#  'Kim Jong Un': {'2018-09-20': 2,
#   '2018-09-21': 1,
#   '2018-09-23': 1,
#   '2018-09-25': 4,
#   '2018-09-26': 1},
#  'Mike Segar/File Photo': {'2018-09-26': 1},
#  'Christine Blasey Ford': {'2018-09-16': 1,
#   '2018-09-17': 3,
#   '2018-09-18': 1,
#   '2018-09-19': 2,
#   '2018-09-20': 2,
#   '2018-09-21': 2,
#   '2018-09-22': 1,
#   '2018-09-24': 1,
#   '2018-09-25': 3},
#  'Rachel Mitchell': {'2018-09-25': 1},
#  'Kamala Harris': {'2018-09-07': 1, '2018-09-25': 1},
#  'Blasey Ford': {'2018-09-25': 1},
#  'Harris': {'2018-09-25': 1},
#  'Deborah Ramirez': {'2018-09-23': 1, '2018-09-24': 1, '2018-09-25': 2},
#  'Verwandte ThemenMcConnell': {'2018-09-25': 1},
#  'Mitch McConnell': {'2018-09-07': 1,
#   '2018-09-16': 1,
#   '2018-09-21': 1,
#   '2018-09-24': 3,
#  'Roscosmos': {'2018-09-22': 2},
#  '” Vladimir Ustimenko': {'2018-09-22': 1},
#  'Crimea': {'2018-09-22': 1},
#  'Soleimani': {'2018-09-22': 1},
#  'CAPABILITIES': {'2018-09-22': 1},
#  'Julian Assange': {'2018-09-21': 3},
#  'Lenin Moreno': {'2018-09-21': 1},
#  'Assange': {'2018-09-21': 1},
#  'Vintimilla': {'2018-09-21': 1},
#  'Moreno': {'2018-09-21': 1},
#  'Peter Nicholls': {'2018-09-21': 1},
#  'Maha El Dahan': {'2018-09-22': 3},
#  'John Stonestreet': {'2018-09-22': 2},
#  'Brian SnyderGunmen': {'2018-09-22': 1},
#  'Ahmed Tolba': {'2018-09-22': 1},
#  '” Yahya Rahim Safavi': {'2018-09-22': 1},
#  'Yaghub Hur Totsari': {'2018-09-22': 1},
#  ...}

# %%
import json
json = json.dumps(datumliste)
f = open("./data/datumliste_en.json","w")
f.write(json)
f.close()

# %% [markdown]
# ## Map personlists together (i.e. "Donald Trump" and "Trump")

# %%
def uniondict(dict1,dict2):
    returndict ={}
    
    allkeys = list(set(list(dict1.keys()) + list(dict2.keys())))
    allvalues = [0] * len(allkeys)
    for i in range(len(allkeys)):
        returndict[allkeys[i]] = allvalues[i]
    
    for key1, value1 in dict1.items():
        returndict[key1] += value1
    for key2, value2 in dict2.items():
        returndict[key2] += value2
                
    return returndict

# %%
def datekompakt(inputdict):
    outputdict = {}

    for name, datelist in inputdict.items():
        for key in inputdict.keys():
            if (name == key):
                continue
            if (name in key) and (len(inputdict[name]) > 3):
                inputdict[name] = uniondict(inputdict[key],datelist)
                inputdict[key] = {}
                break
    for name, datelist  in inputdict.items():
        if datelist != {}:      
            outputdict[name] = datelist
    return outputdict

# %% [markdown]
# ## Clean lists

# %%
datumclean= cleandict_en(datumliste)

# %%
datumkompakt = datekompakt(datumclean)

# %%
import json
json = json.dumps(datumkompakt)
f = open("./data/datumliste_en_clean.json","w")
f.write(json)
f.close()

# %% [markdown]
# ## Lineplots for persons

# %%
def namenplot(name1, name2, startdatum, enddatum, frequenz, savepfad):
    dict1 = datumkompakt[name1]
    dict2 = datumkompakt[name2]

    datelist = pd.date_range(start=startdatum, end=enddatum).tolist()
    datelist = pd.to_datetime((datelist))

    y_name1 =[]
    y_name2 =[]
    for date in datelist:
        if str(date).split()[0] in dict1:
            y_name1.append(dict1[str(date).split()[0]])
        else:
            y_name1.append(0)
        if str(date).split()[0] in dict2:
            y_name2.append(dict2[str(date).split()[0]])
        else:
            y_name2.append(0)

    tickslist = pd.date_range(start=startdatum, end=enddatum, freq=frequenz).tolist()

    plt.plot(datelist, y_name1,label=name1)
    plt.plot(datelist, y_name2,linestyle='--',label=name2)
    max1 = max(y_name1)
    max2 = max(y_name2)
    plt.axis([startdatum, enddatum, 0, max([max1,max2])+3])

    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
    plt.xlabel('Date')
    plt.xticks(tickslist)
    plt.ylabel('Frequecy')
    plt.suptitle('Mentions in the news ' + name1 + " and " + name2)
    plt.gcf().autofmt_xdate()
    plt.legend()
    plt.savefig(savepfad, dpi=300)
    plt.show()

# %%
namenplot("Trump", "Obama", "2018-09-22", "2018-09-26", '1D', './images/trump_obama.png')
